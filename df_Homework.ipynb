# %%
import pandas as pd

# %%
df = pd.read_csv ('data/Minjust2018.csv', header = None, usecols = 9 25)
# Out:
#   File "<ipython-input-15-cf12a3f43471>", line 1
#     df = pd.read_csv ('data/Minjust2018.csv', header = None, usecols = 9 : 25)
#                                                                          ^
# SyntaxError: invalid syntax

# %%
df.fillna('', inplace=True)
df.rename(columns = {27: 'adress'})
# Out:
#                      9            10 25
# 0         96346-3302-КК  3.87437e+06
# 1          4220-3300-ОО  2.18566e+07
# 2        96342-3302-ООО  2.19286e+07
# 3         4199-3300-ООО  2.11822e+07
# 4        81897-3308-ООО  2.19024e+07
# 5         96344-3302-ГП  2.19252e+07
# 6         4079-3301-ООО  2.18892e+07
# 7          4011-3301-РО  2.18566e+07
# 8        75352-3310-ООО   2.1945e+07
# 9         81919-3308-РО  2.18566e+07
# 10       75357-3310-ООО   2.1945e+07
# 11        4233-3300-ООО  2.18565e+07
# 12        98099-3309-КК  2.19449e+07
# 13         4504-3301-ГП  2.18935e+07
# 14                       2.15235e+07
# 15       75307-3310-ООО  2.19449e+07
# 16        75361-3306-КК  2.19449e+07
# 17        4170-3301-ООО  2.18566e+07
# 18        4185-3301-ООО  2.18564e+07
# 19        4147-3301-ООО  2.18564e+07
# 20        4148-3300-ООО  2.18564e+07
# 21        4204-3301-ООО  2.18563e+07
# 22         480-3310-ОАО  3.59943e+06
# 23        4189-3301-ООО  2.18563e+07
# ...

# %%
df.loc([adress]=='Ибраимова')
